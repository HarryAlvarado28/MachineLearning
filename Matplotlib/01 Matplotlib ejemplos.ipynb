# %% [markdown]
# # Matplotlib ejemplos

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(2,9,10)
x
# Out:
# array([2.        , 2.77777778, 3.55555556, 4.33333333, 5.11111111,
#        5.88888889, 6.66666667, 7.44444444, 8.22222222, 9.        ])

# %%
y = x ** 3
y
# Out:
# array([  8.        ,  21.43347051,  44.94924554,  81.37037037,
#        133.51989026, 204.22085048, 296.2962963 , 412.56927298,
#        555.86282579, 729.        ])

# %%
plt.plot(x,y, 'green')
plt.title("Este es mi gráfico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %% [markdown]
# ## Gráficos por columnas o filas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'g')
plt.subplot(1,2,2)
plt.plot(y,x,'red')

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'g')
plt.subplot(2,1,2)
plt.plot(y,x,'red')

# %% [markdown]
# ## Programación orientada a objeto

# %%
figura = plt.figure()
grafico = figura.add_axes([0.1,0.1,0.8,0.8])
grafico.plot(x,y,'green')

# %%
figure = plt.figure()

grafico1 = figure.add_axes([0.1,0.1,0.9,0.9])
grafico1.plot(x,y,'r')

grafico2 = figure.add_axes([0.2,0.4,0.3,0.3])
grafico2.plot(y,x,'blue')

# %% [markdown]
# ## Ejemplo más preparado

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('coherence')

fig.tight_layout()
plt.show()
